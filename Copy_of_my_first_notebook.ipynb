# %% [markdown]
# <a href="https://colab.research.google.com/github/sivaraju4996-debug/my-first-repositay/blob/main/Copy_of_my_first_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
the main difference lies in their physical existence: hardware refers to the tangible,pjysical compenets of computer that you can touch while software consists of the invsible sets of programme that tell the hardware what to do.
HARDWARE :  a key board is a hardware device it takes the input
SOFTWARE: a google chrome
